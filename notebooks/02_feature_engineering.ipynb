# %% [markdown]
# # Feature Engineering
#
# Dataset: India Cancer Patient Dataset (2022–2025)
#
# Goal:
# Develop feature engineering and machine learning techniques to predict cancer patient survival status.

# %% [markdown]
# ---

# %% [markdown]
# ### Setup project dataset
#
# This helps configure the Jupyter notebook to get working directory root and load the dataset.

# %%
import os

from src.preprocessing import load_data

if os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")

print("Current Directory:", os.getcwd())

df = load_data()
# Out:
# Current Directory: C:\Users\Steph\PycharmProjects\cancer-outcome-prediction

# %% [markdown]
# ### 1. Import Libraries
#
#
# Import the libraries required for data preprocessing, feature engineering, model training, evaluation, and visualization.
#
# _Note: The custom module in the `src` directory provides a reusable function for all the features listed above._

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    roc_curve,
    classification_report
)

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier

import pandas as pd
import matplotlib.pyplot as plt

from src.feature_engineering import *

# %% [markdown]
# ### 2. Feature Engineering Pipeline
#
# #### The feature engineering pipeline performs all preprocessing steps before training the machine learning models.
#
# The pipeline includes:
#
# - Converting the diagnosis date into separate year, month, and day features.
# - Removing unnecessary columns such as patient identifiers.
# - Handling missing numerical values using median imputation.
# - Handling missing categorical values using constant imputation.
# - Standardizing numerical features using `StandardScaler`.
# - Encoding categorical variables using `OneHotEncoder`.
# - Splitting the dataset into training and testing sets.

# %% [markdown]
# ### 3. Machine Learning Models
#
# #### The preprocessing pipeline trains and evaluates the following classification models:
#
# - Logistic Regression
# - Decision Tree
# - Random Forest
# - Gradient Boosting
#
# Each model is evaluated using Accuracy, Precision, Recall, F1 Score, and ROC AUC.

# %% [markdown]
# ### 4. Results
#
# #### The preprocessing pipeline outputs:
#
# - Classification report for each model.
# - ROC Curve comparison.
# - Performance comparison table.
# - Best-performing model based on ROC AUC.

# %%
create_preprocessor(df)
# Out:
# Train Shape: (80000, 11)
# Test Shape : (20000, 11)
#
# ...
# Logistic Regression
# ...
#
# Accuracy : 0.9779
# Precision: 0.9791
# Recall   : 0.9779
# F1 Score : 0.9781
# ROC AUC  : 0.9972
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#        Alive       0.94      1.00      0.97      7156
#     Deceased       1.00      0.97      0.98     12844
#
#     accuracy                           0.98     20000
#    macro avg       0.97      0.98      0.98     20000
# weighted avg       0.98      0.98      0.98     20000
#
#
# ...
# Decision Tree
# ...
#
# Accuracy : 0.9729
# Precision: 0.973
# Recall   : 0.9729
# F1 Score : 0.973
# ROC AUC  : 0.9713
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#        Alive       0.96      0.97      0.96      7156
#     Deceased       0.98      0.98      0.98     12844
#
#     accuracy                           0.97     20000
#    macro avg       0.97      0.97      0.97     20000
# ...

# %% [markdown]
# ### Key Outcomes
#
# - Engineered features from the dataset.
# - Removed unnecessary attributes.
# - Used pipelines for preprocessing from Scikit-learn.
# - Trained four classification models.
# - Evaluated model performance using standard metrics.
# - Compared models to identify the strongest performer.
